# %%
import pandas as pd

# %%
df = pd.read_csv('data/test_Batting_Card.csv')

# %%
def get_player_id_by_name(name : str):
    pi = pd.read_pickle('data/players_info.df')
    return pi[pi['player_name'].str.contains(name)]

# %%
vk = get_player_id_by_name('Lara')
print(vk)
# Out:
#     player_id  player_object_id player_name         dob  dod  gender  \
# 33       1982             52337  Brian Lara  1969-05-02  NaN    True
#
#     batting_style    bowling_style  country_id
# 33  left-hand bat  legbreak googly         4.0

# %%
df = pd.read_csv('data/players_info.csv')

# %%
df.columns
# Out:
# Index(['player_id', 'player_object_id', 'player_name', 'dob', 'dod', 'gender',
#        'batting_style', 'bowling_style', 'country_id', 'image_url',
#        'image_metadata'],
#       dtype='object')

# %%
len(df[(df['batsman']==1982) & (df['runs']>399)])
# Out:
# 1
