# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from pandas.api.types import is_numeric_dtype

# %%
df = pd.read_csv('data/batting.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104853 entries, 0 to 104852
# Data columns (total 12 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   gameid    104853 non-null  int64
#  1   innings   104853 non-null  int64
#  2   team      104853 non-null  int64
#  3   batter    104853 non-null  int64
#  4   position  104853 non-null  int64
#  5   runs      104853 non-null  int64
#  6   balls     104853 non-null  int64
#  7   fours     104853 non-null  int64
#  8   sixes     104853 non-null  int64
#  9   out       104853 non-null  object
#  10  fielders  49978 non-null   object
#  11  bowler    104853 non-null  int64
# dtypes: int64(10), object(2)
# memory usage: 9.6+ MB

# %%
def optimize_df(do_optimize = False):
    for col in df.columns:
        if is_numeric_dtype(df[col]):
            if max(df[col]) < np.iinfo(np.uint8).max:
                if do_optimize:
                    df[col] = df[col].astype(np.uint8)
                    print(f"{col} is optimized to: {np.uint8}")
                else:
                    print(f"{col} can be optimized to: {np.uint8}")
            else:
                if np.iinfo(np.uint8).max < max(df[col]) < np.iinfo(np.uint16).max:
                    if do_optimize:
                        df[col] = df[col].astype(np.uint16)
                        print(f"{col} is optimized to: {np.uint16}")
                    else:
                        print(f"{col} can be optimized to: {np.uint16}")
                else:
                    if np.iinfo(np.uint16).max < max(df[col]) < np.iinfo(np.uint32).max:
                        if do_optimize:
                            print(f"{col} is optimized to: {np.uint32}")
                            df[col] = df[col].astype(np.uint32)
                        else:
                            print(f"{col} can be optimized to: {np.uint16}")
                    else:
                        raise Exception("Missed everything")

# %%
optimize_df(True)
df.info()
# Out:
# gameid is optimized to: <class 'numpy.uint32'>
# innings is optimized to: <class 'numpy.uint8'>
# team is optimized to: <class 'numpy.uint8'>
# batter is optimized to: <class 'numpy.uint32'>
# position is optimized to: <class 'numpy.uint8'>
# runs is optimized to: <class 'numpy.uint16'>
# balls is optimized to: <class 'numpy.uint16'>
# fours is optimized to: <class 'numpy.uint8'>
# sixes is optimized to: <class 'numpy.uint8'>
# bowler is optimized to: <class 'numpy.uint32'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104853 entries, 0 to 104852
# Data columns (total 12 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   gameid    104853 non-null  uint32
#  1   innings   104853 non-null  uint8
#  2   team      104853 non-null  uint8
#  3   batter    104853 non-null  uint32
#  4   position  104853 non-null  uint8
#  5   runs      104853 non-null  uint16
#  6   balls     104853 non-null  uint16
#  7   fours     104853 non-null  uint8
#  8   sixes     104853 non-null  uint8
#  9   out       104853 non-null  object
#  10  fielders  49978 non-null   object
#  11  bowler    104853 non-null  uint32
# dtypes: object(2), uint16(2), uint32(3), uint8(5)
# memory usage: 3.7+ MB

# %%
df.to_pickle('data/battingcsv-to-2025.pkl')

# %%
optimize_df(True)
# Out:
# gameid is optimized to: <class 'numpy.uint32'>
# innings is optimized to: <class 'numpy.uint8'>
# team is optimized to: <class 'numpy.uint8'>
# batter is optimized to: <class 'numpy.uint32'>
# position is optimized to: <class 'numpy.uint8'>
# runs is optimized to: <class 'numpy.uint16'>
# balls is optimized to: <class 'numpy.uint16'>
# fours is optimized to: <class 'numpy.uint8'>
# sixes is optimized to: <class 'numpy.uint8'>
# bowler is optimized to: <class 'numpy.uint32'>
