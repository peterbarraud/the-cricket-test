# %%
import pandas as pd
import numpy as np
df = pd.read_pickle('./data/Test Player Innings Stats - All Teams.pkl')

# %%
df.head()
# Out:
#    playername   runs   mins  batted  notout  ballsfaced  fours  sixes  \
# 0    L Hutton  364.0  797.0    True   False       847.0   35.0    0.0
# 1  WR Hammond  336.0  318.0    True    True         NaN   34.0   10.0
# 2    GA Gooch  333.0  628.0    True   False       485.0   43.0    3.0
# 3   A Sandham  325.0  600.0    True   False       640.0   28.0    0.0
# 4   JH Edrich  310.0  532.0    True    True       450.0   52.0    5.0
#
#    inningsnumber     opposition    ground        date  country  \
# 0              1    v Australia  The Oval  1938/08/20  England
# 1              2  v New Zealand  Auckland  1933/03/31  England
# 2              1        v India    Lord's  1990/07/26  England
# 3              1  v West Indies  Kingston  1930/04/03  England
# 4              1  v New Zealand     Leeds  1965/07/08  England
#
#    numoversbowled  oversbowled  maidens  runsconceded  wickets
# 0             NaN          NaN      NaN           NaN      NaN
# ...

# %%
df[(df.batted == False) & (pd.isna(df.runs)) & (pd.isna(num))]
# Out:
#                   playername  runs  mins  batted  notout  ballsfaced  fours  \
# 17691           J Southerton   NaN   NaN   False   False         NaN    NaN
# 17692             T Armitage   NaN   NaN   False   False         NaN    NaN
# 17693   James Lillywhite jnr   NaN   NaN   False   False         NaN    NaN
# 17694               F Morley   NaN   NaN   False   False         NaN    NaN
# 17695               AG Steel   NaN   NaN   False   False         NaN    NaN
# 17696                 A Shaw   NaN   NaN   False   False         NaN    NaN
# 17697            Lord Harris   NaN   NaN   False   False         NaN    NaN
# 17698               T Emmett   NaN   NaN   False   False         NaN    NaN
# 17699              R Pilling   NaN   NaN   False   False         NaN    NaN
# 17700       A Shrewsbury snr   NaN   NaN   False   False         NaN    NaN
# 17701           WE Midwinter   NaN   NaN   False   False         NaN    NaN
# ...

# %%
df.loc[17691]
# Out:
# playername        J Southerton
# runs                       nan
# mins                       nan
# batted                   False
# notout                   False
# ballsfaced                 nan
# fours                      nan
# sixes                      nan
# inningsnumber                4
# opposition         v Australia
# ground               Melbourne
# date                1877/03/31
# country                England
# numoversbowled             nan
# oversbowled                nan
# maidens                    nan
# runsconceded               nan
# wickets                    nan
# Name: 17691, dtype: object
